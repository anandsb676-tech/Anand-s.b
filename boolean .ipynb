# %%
print("===FARMERS INPUT BASED PROFIT ANALYSIS=== ")
seed_cost=float(input("enter seed cost(INR):"))
fertilizer_cost=float(input("enter fertilzer cost(INR):"))
pesticide_cost=float(input("enter pesticide cost(INR)"))
labor_cost=float(input("enter labor cost(INR)"))
irrigation_cost=(float(input("enter irrigation cost(INR)")))
total_input_cost=seed_cost+fertilizer_cost+pesticide_cost+labor_cost+irrigation_cost
print("\nTotal input cost(INR):",total_input_cost)

total_yield_kg=float(input("\nenter selling price:"))
price_per_kg=float(input("enter selling price(INR):"))
total_revenue=total_yield_kg*price_per_kg
print("total revenue(INR):",total_revenue)
profit=total_revenue-total_input_cost
print("net profit/loss(INR):",profit)

profit_per_kg=profit/total_yield_kg
print("profit per kg(INR):",profit_per_kg)

total_seed_kg=float(input("\nenter total seed available(KG):"))
seed_bag_capacity=float(input("enter seed bag capacity(KG)"))
full_seed_bag=total_seed_kg//seed_bag_capacity
remaining_seed=total_seed_kg%seed_bag_capacity
print("full seed bag used:",full_seed_bag)
print("remaining seeds(KG):",remaining_seed)

initial_crop_units=float(input("\nenter initial crop units:"))
growth_rate=float(input("enter seasonal growth rate(eg,1.10 for 10%)"))
seasons=int(input("enter number of seasons"))
expected_crop=initial_crop_units*growth_rate**seasons
print("expected crop after seasons:",expected_crop)

weather_loss=float(input("\nenter loss due to weather(INR,enter positive value:)"))
weather_loss=weather_loss
adjusted_profit=profit=weather_loss

print("adjusted profit after weaher impact(INR):",adjusted_profit)
# Out:
# ===FARMERS INPUT BASED PROFIT ANALYSIS===
# enter seed cost(INR):565
# enter fertilzer cost(INR):641654
# enter pesticide cost(INR)232163
# enter labor cost(INR)2313
# enter irrigation cost(INR)2326
#
# Total input cost(INR): 879021.0
#
# enter selling price:2321
# enter selling price(INR):2323
# total revenue(INR): 5391683.0
# net profit/loss(INR): 4512662.0
# profit per kg(INR): 1944.2748815165876
#
# enter total seed available(KG):2322
# enter seed bag capacity(KG)223
# full seed bag used: 10.0
# remaining seeds(KG): 92.0
#
# enter initial crop units:32632
# enter seasonal growth rate(eg,1.10 for 10%)1.3
# enter number of seasons3
# expected crop after seasons: 71692.504
#
# enter loss due to weather(INR,enter positive value:)45454454
# adjusted profit after weaher impact(INR): 45454454.0

# %%
a=10
b=6
print("bitwise AND(&):",a&b)
print("bitwise OR(/):",a/b)
print("bitwise XOR(^):",a^b)
print("bitwise NOT (~a):",~a)
print("left shift(a<<1):",a<<1)
print("right shift(a>>1)",a>>1)
# Out:
# bitwise AND(&): 2
# bitwise OR(/): 1.6666666666666667
# bitwise XOR(^): 12
# bitwise NOT (~a): -11
# left shift(a<<1): 20
# right shift(a>>1) 5

# %%
a=float(input("enter a value:"))
print("initial value:",a)
a+=5
print("after+=:",a)
a-=3
print("after-=:",a)
a*=2
print("after*=:",a)
a/=4
print("after/=4:",a)
a//=2
print("after//=2:",a)
a%=3
print("after%=3:",a)
a**=2
print("after**=:",a)
# Out:
# enter a value:41
# initial value: 41.0
# after+=: 46.0
# after-=: 43.0
# after*=: 86.0
# after/=4: 21.5
# after//=2: 10.0
# after%=3: 1.0
# after**=: 1.0

# %%
x=float(input("enter x:"))
y=float(input("enter y:"))
print("x==y:",x==y)
print("x!=y:",x!=y)
print("x>y:",x>y)
print("x<y:",x<y)
print("x>=y:",x>=y)
print("x<=y:",x<=y)
# Out:
# enter x:8484
# enter y:949847
# x==y: False
# x!=y: True
# x>y: False
# x<y: True
# x>=y: False
# x<=y: True

# %%
rainfall=True
soil_moisture=False
print("AND:",rainfall and soil_moisture)
print("OR:",rainfall or soil_moisture)
print("NOT:",not rainfall)
# Out:
# AND: False
# OR: True
# NOT: False

# %%
a=[1,2,3]
b=a
b.append(4)
c=[1,2,3]
print("a is b:",a is b)
print("a is c:",a is c)
print("a is not c:",a is not c)
# Out:
# a is b: True
# a is c: False
# a is not c: True

# %%
crops=["rice","whaet","maize"]
print("rice in crops:","rice" in crops)
print("barley in crops:","barley"in crops)
print("barley not in crops:","barley"not in crops)
# Out:
# rice in crops: True
# barley in crops: False
# barley not in crops: True

# %%
a=float(input("enter number:"))
b=float(input("enter number:"))
print("A=",a)
print("B=",b)

sum=a+b
dif=a-b
print("sum of A+B:",sum)
print("dif of A-B:",dif)

prod=a*b
div=a/b

print("prod of A*B:",prod)

print("div of A/B:",div)
# Out:
# enter number:45959

# %%
box=["red","blue","yellow"]
print("white in box:","white" in box)
print("blue in box:","blue" in box)
print("yellow not in box:","yellow"not in box)
