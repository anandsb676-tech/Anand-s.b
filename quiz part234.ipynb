# %%
li=['harsh','pratik','bob','dhruv']
print(li[1][-1])
print(li[3][2])
print(li[0][4])
print(li[-2][2])
# Out:
# k
# r
# h
# b

# %%
a=[1998,2002]
b=[2014,2016]
print((a+b)*3)
print((a+b)*2)
# Out:
# [1998, 2002, 2014, 2016, 1998, 2002, 2014, 2016, 1998, 2002, 2014, 2016]
# [1998, 2002, 2014, 2016, 1998, 2002, 2014, 2016]

# %%
a=[1,2,3,4,5]
b=a
b[0]=78
b[4]=345785
print(a)
# Out:
# [78, 2, 3, 4, 345785]

# %%
def gfg(x,li=[]):
  for i in range(x):
    li.append(i*i)
    print(li)

gfg(3,[3,2,1])
# Out:
# [3, 2, 1, 0]
# [3, 2, 1, 0, 1]
# [3, 2, 1, 0, 1, 4]

# %%
def reverse(a):
  a.reverse()
  return a
def yknjs(a):
  b=[]
  b.extend(reverse(a))
  print(b)
a=[1,3.3,5.31,7.531]
yknjs(a)
# Out:
# [7.531, 5.31, 3.3, 1]

# %%
a=[]
a.append([1,[2,3],4])
a.extend([7,8,9])
print(a)
print(a[0][1][1]+a[2])
# Out:
# [[1, [2, 3], 4], 7, 8, 9]
# 11

# %%
li=[1,1.33,'gfg',0,'no',None,'g',True]
val1,val2=0,''
for x in li:
  if(type(x)==int or type(x)==float):
    val1 +=x
  elif(type(x)==str):
    val2 +=x
  else:
    break
  print(val1,val2)
# Out:
# 1
# 2.33
# 2.33 gfg
# 2.33 gfg
# 2.33 gfgno

# %%
var=10
for i in range(10):
  for j in range(2,10,1):
    if var%2==0:
      continue
    else:
     var+=1
print(var)
# Out:
# 10

# %%
a=['geeks','for','geeks','jkxvh']

b=[i[1].upper() for i in a]
print(b)
# Out:
# ['E', 'O', 'E', 'K']

# %%
x="GFG"
for i in range(x):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3199161061.py in <cell line: 0>()
#       1 x="GFG"
# ----> 2 for i in range(x):
#       3   print(i)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
while True:
  print("Greeks!")
  break
# Out:
# Greeks!

# %%
i=1
while True:
  if i%7==0:
    break
  print(i,end="")
  i+=1
# Out:
# 123456

# %%
li=['a','s','d','f','g','h','j','k']
print(li[1:-3])
# Out:
# ['s', 'd', 'f', 'g']

# %%
li=[1,2,3,4]
li.append([5,6,7,8])
sjkvv=li.extend([4,5,6,7,8,9,0])
print(sjkvv)

print(li)
# Out:
# None
# [1, 2, 3, 4, [5, 6, 7, 8], 4, 5, 6, 7, 8, 9, 0]

# %%
def addtolist(a):
  a+=[10]
b=[10,20,30,40]
addtolist(b)
print(len(b))
# Out:
# 5

# %%
a=[x for x in range(5)]
b=[x for x in range(7) if x in a and x%2==0]
print(b)
# Out:
# [0, 2, 4]

# %%
num=10
while num>0:
  if num%2==0:
    print(num," ",end="")
  num-=1
# Out:
# 10  8  6  4  2

# %%
a=[1,2,3,4]
b=a
c=a.copy()
d=a
a[0]=[99]
print(a,b,c,d)
# Out:
# [[99], 2, 3, 4] [[99], 2, 3, 4] [1, 2, 3, 4] [[99], 2, 3, 4]

# %%
li=[1,3,5,7,9]
print(li.pop(-3),end="")
# Out:
# 5

# %%
a=[10,20,30,40,50]
b=[1,2,3,4,5]
sub=list()
for a,b in zip(a,b):
  item=a-b
  sub.append(item)
  print(sub)
# Out:
# [9]
# [9, 18]
# [9, 18, 27]
# [9, 18, 27, 36]
# [9, 18, 27, 36, 45]

# %%
for num in range(10,14):
  for i in range(2,num):
    if num%i==1:
      print(num)
      break
# Out:
# 10
# 11
# 12
# 13

# %%
x="abcdfvvavfdvdfvag"
print(len(x))
for i in range(len(x)):
 print(i,end="")
# Out:
# 31
# 0123456789101112131415161718192021222324252627282930
